# %% [markdown]
# # Notes

# %% [markdown]
# # how to add the stem files name when I want to run the script? e.g adding 4 files every times!
# # directory ='/'
# # if not !!!
# # does parsh interactive shell program?
# # ephemeris files? do need to download them for all the files? if the file has EPHVER mean is standard!
# # why there is diffirence between J B names?
# # what the difference when we use dedespers or the scrunch polarizarion to produce the average profile?
# # why there is difference between snr of psrstat and the actual value when we plot it?
#
# # time and freq resolve?

# %%
import os

# %%
#changing to new work directory 
dir_ = os.chdir(os.path.realpath('/data0/abubakr/B0138+59/raw/'))

# %%
ls
# Out:
# ?
# B0138+59_D20130422T110304_30_255_MP.ar
# B0138+59_D20130422T110304_31_225_MP.ar
# B0138+59_D20130422T110305_31_286_MP.ar
# B0138+59_D20130422T110305_31_347_MP.ar
# B0138+59_D20130422T110306_30_438_MP.ar
# B0138+59_D20130430T101124_31_225_MP.ar
# B0138+59_D20130430T101125_30_255_MP.ar
# B0138+59_D20130430T101126_30_316_MP.ar
# B0138+59_D20130430T101127_31_347_MP.ar
# B0138+59_D20130430T101128_30_377_MP.ar
# B0138+59_D20130430T101130_30_438_MP.ar
# B0138+59_D20130507T101644_30_255_MP.ar
# B0138+59_D20130507T101644_31_225_MP.ar
# B0138+59_D20130507T101646_30_316_MP.ar
# B0138+59_D20130507T101646_31_286_MP.ar
# B0138+59_D20130507T101648_30_377_MP.ar
# B0138+59_D20130507T101649_31_408_MP.ar
# B0138+59_D20130507T101650_30_438_MP.ar
# B0138+59_D20130513T093034_30_255_MP.ar
# B0138+59_D20130513T093034_31_286_MP.ar
# B0138+59_D20130513T093035_30_316_MP.ar
# B0138+59_D20130513T093037_31_408_MP.ar
# B0138+59_D20130513T093038_30_438_MP.ar
# B0138+59_D20130523T120339_30_255_MP.ar
# ...

# %%
# %run reduceSingleStation_modefy.py --help #stem="B0138+59_D20160801T051201"
# Out:
# usage: reduceSingleStation.py --stem <stemName> [options]
#
# Reduce LOFAR single station TimerArchive data. Version 1.2
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --indir <inputDir>    specify the input data directory.
#   --outdir <outputDir>  specify output directory
#   --eph <ephemFile>     use ephemeris file to update archives
#   --psrsh               write zap commands to psrsh script file
#   --stem <stemName>     filename stem PSR_DYYYYMMDDTHHMMSS
#   -t, --tscr            time scrunch and write out the file
#
# Copyright (C) 2017 by Maciej Serylak

# %%
#changing to new work directory 
dir_ = os.chdir(os.path.realpath('/data0/abubakr/B1133+16_result/'))

# %%
ls
# Out:
# B1133+16_D20140421T203736.ar.pscr
# B1133+16_D20140421T203736.ar.pscr.zap
# B1133+16_D20140421T203736.ar.pscr.zap.F
# B1133+16_D20140421T203736.ar.pscr.zap.T
# B1133+16_D20140421T203736.psh
# B1133+16_D20140427T204840.ar.pscr
# B1133+16_D20140427T204840.ar.pscr.zap
# B1133+16_D20140427T204840.ar.pscr.zap.F
# B1133+16_D20140427T204840.ar.pscr.zap.T
# B1133+16_D20140427T204840.psh
# B1133+16_D20140727T145200.ar.pscr
# B1133+16_D20140727T145200.ar.pscr.zap
# B1133+16_D20140727T145200.ar.pscr.zap.F
# B1133+16_D20140727T145200.ar.pscr.zap.T
# B1133+16_D20140727T145200.psh
# B1133+16_D20140817T135201.ar.pscr
# B1133+16_D20140817T135201.ar.pscr.zap
# B1133+16_D20140817T135201.ar.pscr.zap.F
# B1133+16_D20140817T135201.ar.pscr.zap.T
# B1133+16_D20140817T135201.psh
# B1133+16_D20140824T121701.ar.pscr
# B1133+16_D20140824T121701.ar.pscr.zap
# B1133+16_D20140824T121701.ar.pscr.zap.F
# B1133+16_D20140824T121701.ar.pscr.zap.T
# B1133+16_D20140824T121701.psh
# B1133+16_D20140907T121701.ar.pscr
# ...
